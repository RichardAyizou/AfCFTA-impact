# %% [markdown]
# # Data from BCEAO

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Commerce extérieur

# %%
commerce_exterieur = pd.read_excel("data/bceao-ce.xlsx")
commerce_exterieur.head()
# Out:
#             Pays  Année  Exportations totales  \
# 0  COTE D'IVOIRE   1960                   NaN
# 1  COTE D'IVOIRE   1961                   NaN
# 2  COTE D'IVOIRE   1962                   NaN
# 3  COTE D'IVOIRE   1963                   NaN
# 4  COTE D'IVOIRE   1964               73186.0
#
#    Exportations de produits du cacao  Exportations de cacao en fèves  \
# 0                                NaN                             NaN
# 1                                NaN                             NaN
# 2                                NaN                             NaN
# 3                                NaN                             NaN
# 4                            14001.9                         13955.0
#
#    Exportations de cacao en produits transformés  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# ...

# %% [markdown]
# ### Comptabilité nationale

# %%
compta_nat = pd.read_excel("data/bceao-comptanat.xlsx")
compta_nat.head()
# Out:
#             Pays  Année valeur ajoutee du secteur des extractions   \
# 0  COTE D'IVOIRE   1960                                          -
# 1  COTE D'IVOIRE   1961                                          -
# 2  COTE D'IVOIRE   1962                                          -
# 3  COTE D'IVOIRE   1963                                          -
# 4  COTE D'IVOIRE   1964                                          -
#
#   valeur ajoutee des industries  Valeur ajoutee des gaz, eau, electricite  \
# 0                           19.9                                        -
# 1                           24.7                                        -
# 2                           27.4                                        -
# 3                           30.2                                        -
# 4                             36                                        -
#
#   Valeur ajoutee des bÃ¢timents et travaux publics aux PIB  \
# 0                                                  -
# ...
